# %% [markdown]
# # Курсовая работа студента факультета искусственного интеллекта онлайн-университета [Geek University](https://geekbrains.ru/geek_university)
#
# ## В рамках курса "Python для Data Science"
#
# **Автор**: Кабанов Сергей
# **Преподаватель**: Ширкин Сергей
#
# **Материалы к проекту (файлы)**:
# train.csv
# test.csv
#
# **Задание**:
# Используя данные из train.csv, построить модель для предсказания цен на недвижимость (квартиры). С помощью полученной модели предсказать цены для квартир из файла test.csv.
#
# **Целевая переменная**:
# Price
#
# **Основная метрика**:
# R2 - коэффициент детерминации (sklearn.metrics.r2_score)
#
# **Вспомогательная метрика**:
# MSE - средняя квадратичная ошибка (sklearn.metrics.mean_squared_error)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor as RF
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score as r2, mean_squared_error as mse

# %%
RANDOM_STATE = 42

# %%
TRAIN_DATA_FILE = 'train.csv'
TEST_DATA_FILE = 'test.csv'

# %% [markdown]
# ### Data load

# %%
data_train = pd.read_csv(TRAIN_DATA_FILE)
data_test = pd.read_csv(TEST_DATA_FILE)

# %%
data_train.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.930730
# 1         1         240.0            1       16       B  300009.450063
# 2         0         229.0            1        3       B  220925.908524
# 3         3        1084.0            0        5       B  175616.227217
# 4         1        2078.0            2        4       B  150226.531644

# %%
data_train.describe().T
# Out:
#                  count           mean            std           min  \
# Id             10000.0    8383.407700    4859.019020      0.000000
# DistrictId     10000.0      50.400800      43.587592      0.000000
# Rooms          10000.0       1.890500       0.839512      0.000000
# Square         10000.0      56.315775      21.058732      1.136859
# LifeSquare      7887.0      37.199645      86.241209      0.370619
# KitchenSquare  10000.0       6.273300      28.560917      0.000000
# Floor          10000.0       8.526700       5.241148      1.000000
# HouseFloor     10000.0      12.609400       6.775974      0.000000
# HouseYear      10000.0    3990.166300  200500.261427   1910.000000
# Ecology_1      10000.0       0.118858       0.119025      0.000000
# Social_1       10000.0      24.687000      17.532614      0.000000
# Social_2       10000.0    5352.157400    4006.799803    168.000000
# Social_3       10000.0       8.039200      23.831875      0.000000
# Healthcare_1    5202.0    1142.904460    1021.517264      0.000000
# Helthcare_2    10000.0       1.319500       1.493601      0.000000
# Shops_1        10000.0       4.231300       4.806341      0.000000
# Price          10000.0  214138.857399   92872.293865  59174.778028
#
#                          25%            50%            75%           max
# Id               4169.500000    8394.500000   12592.500000  1.679800e+04
# DistrictId         20.000000      36.000000      75.000000  2.090000e+02
# Rooms               1.000000       2.000000       2.000000  1.900000e+01
# Square             41.774881      52.513310      65.900625  6.410652e+02
# LifeSquare         22.769832      32.781260      45.128803  7.480592e+03
# KitchenSquare       1.000000       6.000000       9.000000  2.014000e+03
# Floor               4.000000       7.000000      12.000000  4.200000e+01
# HouseFloor          9.000000      13.000000      17.000000  1.170000e+02
# HouseYear        1974.000000    1977.000000    2001.000000  2.005201e+07
# Ecology_1           0.017647       0.075424       0.195781  5.218671e-01
# Social_1            6.000000      25.000000      36.000000  7.400000e+01
# Social_2         1564.000000    5285.000000    7227.000000  1.908300e+04
# Social_3            0.000000       2.000000       5.000000  1.410000e+02
# Healthcare_1      350.000000     900.000000    1548.000000  4.849000e+03
# Helthcare_2         0.000000       1.000000       2.000000  6.000000e+00
# Shops_1             1.000000       3.000000       6.000000  2.300000e+01
# Price          153872.633942  192269.644879  249135.462171  6.332335e+05

# %% [markdown]
# ### Init data prepare

# %%
# посмотрим на слишком большие знаечения поля HouseYear
data_train.loc[data_train['HouseYear'] > 2020]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109    1.0  37.265070   20.239714            9.0      9
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1497        12.0   20052011   0.136330         B         B        30
# 4189         9.0       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1497      6141        10         262.0            3        6       B
# 4189      4756        16        2857.0            5        8       B
#
#               Price
# 1497  254084.534396
# 4189  243028.603096

# %%
# заменим 20052011 на 2005
data_train.loc[data_train['HouseYear'] == 20052011, 'HouseYear'] = 2005

# заменим 4968 на 1968
data_train.loc[data_train['HouseYear'] == 4968, 'HouseYear'] = 1968

# %%
# посмотрим на большие значения поля HouseFloor
data_train.loc[data_train['HouseFloor'] > 50]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 6131  10806           5    1.0  51.944587   48.709601            1.0      6
# 8599   9300          74    2.0  71.747869   74.579809            9.0      5
# 8854     78          30    2.0  65.773749   66.811789            1.0      8
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6131        99.0       1977   0.150818         B         B        16
# 8599        99.0       1977   0.075779         B         B         6
# 8854       117.0       1977   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 6131      3433         4        2643.0            4        5       B
# 8599      1437         3           NaN            0        2       B
# 8854      6398       141        1046.0            3       23       B
#
#               Price
# 6131  296127.115515
# 8599  243329.912579
# 8854  207248.370520

# %%
# заменим 99 на 9
data_train.loc[data_train['HouseFloor'] == 99, 'HouseFloor'] = 9

# заменим 117 на 17
data_train.loc[data_train['HouseFloor'] == 117, 'HouseFloor'] = 17

# %%
# посмотрим на квартиры с очень большой площадью, оставим только понятные столбцы
data_train.loc[data_train['Square'] > 200, ['Id', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
                                            'Floor', 'HouseFloor', 'Price']]
# Out:
#          Id  Rooms      Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 1981   7917    0.0  212.932361  211.231125            0.0      2         3.0
# 1982   5548    5.0  275.645284  233.949309           26.0     12        37.0
# 4262     28    2.0  604.705972         NaN            1.0     17        18.0
# 4690   2307    1.0  409.425181  410.639749           10.0      4         4.0
# 6977  11602    2.0  641.065193  638.163193           10.0     20        19.0
# 9910  16568    4.0  200.334539  201.627361           25.0      1         2.0
#
#               Price
# 1981  302211.260887
# 1982  455264.882666
# 4262  187717.242538
# 4690   90470.430830
# 6977  133529.681562
# 9910  528560.506016

# %%
# Похоже, что у квартиры с Id 28, 2307, 11602 судя по их стоимости ошибка в полях LifeSquare и Square. 
# Значения завышены в 10 раз. Для остальных квартир площадь выглядит нормально.
# уменьшим площади в 10 раз для данных квартир
data_train.loc[data_train['Id'].isin([28, 2307, 11602]), ['Square', 'LifeSquare']] = \
                                        data_train.loc[data_train['Id'].isin([28, 2307, 11602]), ['Square', 'LifeSquare']] / 10

# %%
# посмотрим на квартиры с большим количеством комнат
data_train.loc[data_train['Rooms'] > 5]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
# 1454   8491           1   19.0  42.006046   21.779288            7.0     17
# 2170  14003          99    6.0  59.414334   38.702244            6.0      7
# 8849  14865           9   10.0  60.871266   38.420681           10.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 377         22.0       2002   0.090799         B         B        74
# 1454        17.0       2014   0.007122         B         B         1
# 2170         9.0       1969   0.033494         B         B        66
# 8849         2.0       1994   0.161532         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 377      19083         2           NaN            5       15       B
# 1454       264         0           NaN            0        1       B
# 2170     10573         1        1322.0            3        8       B
# 8849      5648         1          30.0            2        4       B
#
#               Price
# 377   317265.323792
# 1454   78364.616704
# 2170  229661.964416
# 8849  172329.270863

# %%
# посмотрим медианные значения площади для 1, 2 и 3 комнатных квартир
data_train.loc[data_train['Rooms'].isin([1,2,3]), ['Rooms', 'Square']].groupby(by='Rooms').median()
# Out:
#           Square
# Rooms
# 1.0    40.406590
# 2.0    55.841812
# 3.0    77.413643

# %%
# заменим значения для квартир с аномально большим количеством комнат на медианные
data_train.loc[data_train['Id'].isin([5927, 14003, 14865]), 'Rooms'] = 2
data_train.loc[data_train['Id'] == 8491, 'Rooms'] = 1

# %% [markdown]
# ### Train test split

# %%
train, valid = train_test_split(data_train, test_size=0.25, random_state=RANDOM_STATE)

# %% [markdown]
# ### Data prepare

# %%
# посчитаем различные статистики по train
# количество квартир в районе:
stats_distr_1 = train['DistrictId'].value_counts(normalize=True).reset_index().\
                                                                 rename(columns={'index':'DistrictId', 
                                                                                 'DistrictId':'flat_qty_distr'})

# средняя цена за квартиру по районам и кол-ву комнат
stats_distr_rooms_1 = train.groupby(['DistrictId', 'Rooms'], as_index=False)[['Price']].mean().\
                                                                            rename(columns={'Price':'mean_price_distr_rooms'})

# средняя цена за квартиру по кол-ву комнат
stats_rooms_1 = train.groupby(['Rooms'], as_index=False)[['Price']].mean().rename(columns={'Price':'mean_price_rooms'})

# медианная площадь по району и кол-ву комнат
stats_distr_rooms_2 = train.groupby(['DistrictId', 'Rooms'], as_index=False)[['Square']].median().\
                                                                            rename(columns={'Square':'mean_square_distr_rooms'})

# медианная площадь по кол-ву комнат
stats_rooms_2 = train.groupby(['Rooms'], as_index=False)[['Square']].median().\
                                                                            rename(columns={'Square':'mean_square_rooms'})

# средняя цена за квадратный метр
stats_sq_price = train.groupby(['DistrictId', 'Rooms'], as_index=False)[['Price']].mean().\
                                                                            rename(columns={'Price':'mean_price_distr_rooms'})

# %%
# Объявим необходимые функции
def prepare_category(df, cat_feats=['Ecology_2', 'Ecology_3', 'Shops_2']):
    ''' Приводит категориальные признаки к числовым
    '''
    df_copy = df.copy()
    for f in cat_feats:
        df_copy.loc[:, f] = df[f].map({'A': 1, 'B': 0})
    return df_copy


def add_stat_distr_1(df, stats=stats_distr_1):
    ''' Добавляет статистику "количество квартир в районе"
    '''
    df_copy = df.copy()
    df_copy = pd.merge(df_copy, stats, on='DistrictId', how='left')
    df_copy['flat_qty_distr'] = df_copy['flat_qty_distr'].fillna(stats['flat_qty_distr'].min())
    return df_copy


def add_stat_distr_rooms(df, stats_1=stats_distr_rooms_1, stats_2=stats_rooms_1):
    ''' Добавляет статистики "средняя цена за квартиру по районам и кол-ву комнат" и
        "средняя цена за квартиру по кол-ву комнат"
    '''
    df_copy = df.copy()
    df_copy = pd.merge(df_copy, stats_1, on=['DistrictId', 'Rooms'], how='left')
    df_copy = pd.merge(df_copy, stats_2, on='Rooms', how='left')
    
    df_copy['mean_price_rooms'] = df_copy['mean_price_rooms'].fillna(stats_2['mean_price_rooms'].mean())
    df_copy['mean_price_distr_rooms'] = df_copy['mean_price_distr_rooms'].fillna(df_copy['mean_price_rooms'])
    return df_copy


def add_stat_distr_rooms_2(df, stats_1=stats_distr_rooms_2, stats_2=stats_rooms_2):
    ''' Добавляет статистики "медианная площадь по району и кол-ву комнат" и
        "медианная площадь по кол-ву комнат"
    '''
    df_copy = df.copy()
    df_copy = pd.merge(df_copy, stats_1, on=['DistrictId', 'Rooms'], how='left')
    df_copy = pd.merge(df_copy, stats_2, on='Rooms', how='left')
    
    df_copy['mean_square_rooms'] = df_copy['mean_square_rooms'].fillna(stats_2['mean_square_rooms'].mean())
    df_copy['mean_square_distr_rooms'] = df_copy['mean_square_distr_rooms'].fillna(df_copy['mean_square_rooms'])
    return df_copy


def add_stat_square_price(df, stats):
    ''' Добавляет статистику "средняя цена за квадратный метр"
    '''
    df_copy = df.copy()
    df_copy = pd.merge(df_copy, stats, on='Rooms', how='left')
    df_copy['mean_square_price'] = df_copy['mean_square_price'].fillna(stats['mean_square_price'].mean())
    return df_copy


def fillna_Healthcare_1(df):
    ''' Заменяет nan в поле Healthcare_1 на 0
    '''
    df_copy = df.copy()
    df_copy['Healthcare_1'] = df_copy['Healthcare_1'].fillna(0)
    return df_copy


def fillna_LifeSquare(df, source_df):
    ''' Заполняет LifeSquare средним значением
    '''
    df_copy = df.copy()
    df_copy['LifeSquare'] = df_copy['LifeSquare'].fillna(source_df['LifeSquare'].mean())
    return df_copy


def add_square_price(df):
    ''' Добавить признак цена за квадратный метр (только для train)
    '''
    df_copy = df.copy()
    df_copy['square_price'] = df_copy['Price'] / df_copy['Square']
    return df_copy


def prepare_LifeSquare(df, source_df):
    ''' Заменяем все аномально большие значения на среднее
    '''
    df_copy = df.copy()
    df_copy.loc[df_copy['LifeSquare'] > 250, 'LifeSquare'] = source_df['LifeSquare'].mean()
    return df_copy


def prepare_KitchenSquare(df, source_df):
    ''' Заменяем все аномально большие значения на среднее
    '''
    df_copy = df.copy()
    df_copy.loc[df_copy['KitchenSquare'] > 250, 'KitchenSquare'] = source_df['KitchenSquare'].mean()
    return df_copy

# %%
train = add_square_price(train)

# средняя цена за квадратный метр
stats_square_price_mean = train.groupby(['Rooms'], as_index=False)[['square_price']]\
    .mean().rename(columns={'square_price':'mean_square_price'})

train = add_stat_distr_1(train)
valid = add_stat_distr_1(valid)

train = add_stat_distr_rooms(train)
valid = add_stat_distr_rooms(valid)

train = add_stat_distr_rooms_2(train)
valid = add_stat_distr_rooms_2(valid)

train = add_stat_square_price(train, stats_square_price_mean)
valid = add_stat_square_price(valid, stats_square_price_mean)

train = fillna_Healthcare_1(train)
valid = fillna_Healthcare_1(valid)

train = fillna_LifeSquare(train, train)
valid = fillna_LifeSquare(valid, train)

train = prepare_category(train)
valid = prepare_category(valid)

train = prepare_LifeSquare(train, train)
valid = prepare_LifeSquare(valid, train)

train = prepare_KitchenSquare(train, train)
valid = prepare_KitchenSquare(valid, train)

# %% [markdown]
# ### Model

# %%
def fit_and_score(model, X_train, X_valid, y_train, y_valid):
    model.fit(X_train, y_train.values.ravel())
    y_train_pred = model.predict(X_train)
    y_valid_pred = model.predict(X_valid)
    r2_train = r2(y_train, y_train_pred)
    r2_valid = r2(y_valid, y_valid_pred)
    return r2_train, r2_valid

# %%
rf = RF(random_state=RANDOM_STATE,
        n_estimators=1000,
        max_depth=17,
        max_features=6,
        n_jobs=-1)

# %%
feats = [
    'DistrictId',
    'Rooms', 
    'Square', 
    'LifeSquare', 
    'KitchenSquare',
    'Floor',
    'HouseFloor',
    'HouseYear',
    'Ecology_1',
    'Ecology_2',
    'Ecology_3', 
    'Social_1', 
    'Social_2',
    'Social_3', 
    'Healthcare_1',
    'Helthcare_2',
    'Shops_1',
    'Shops_2', 
    'flat_qty_distr',
#     'mean_price_distr_rooms',
    'mean_price_rooms', 
#     'mean_square_distr_rooms',
#     'mean_square_rooms',
    'mean_square_price'
]

target = ['Price']

# %%
fit_and_score(rf, train[feats], valid[feats], train[target], valid[target])
# Out:
# (0.9536981479524923, 0.7349390532041377)

# %% [markdown]
# ### Подбор параметров модели

# %%
parameters = [{'n_estimators': [150, 200, 250], 
               'max_features': np.arange(5, 9),
               'max_depth': np.arange(5, 15)}]

clf = GridSearchCV(estimator=RF(random_state=RANDOM_STATE, n_jobs=-1), 
                   param_grid=parameters,
                   scoring='r2',
                   cv=5)

clf.fit(train[feats], train[target].values.ravel())

# %%
clf.best_params_
# Out:
# {'max_depth': 14, 'max_features': 6, 'n_estimators': 250}

# %%
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']

for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# 0.641 (+/-0.027) for {'max_depth': 5, 'max_features': 5, 'n_estimators': 150}
# 0.640 (+/-0.027) for {'max_depth': 5, 'max_features': 5, 'n_estimators': 200}
# 0.641 (+/-0.028) for {'max_depth': 5, 'max_features': 5, 'n_estimators': 250}
# 0.646 (+/-0.032) for {'max_depth': 5, 'max_features': 6, 'n_estimators': 150}
# 0.646 (+/-0.031) for {'max_depth': 5, 'max_features': 6, 'n_estimators': 200}
# 0.647 (+/-0.030) for {'max_depth': 5, 'max_features': 6, 'n_estimators': 250}
# 0.648 (+/-0.029) for {'max_depth': 5, 'max_features': 7, 'n_estimators': 150}
# 0.648 (+/-0.029) for {'max_depth': 5, 'max_features': 7, 'n_estimators': 200}
# 0.650 (+/-0.030) for {'max_depth': 5, 'max_features': 7, 'n_estimators': 250}
# 0.654 (+/-0.032) for {'max_depth': 5, 'max_features': 8, 'n_estimators': 150}
# 0.654 (+/-0.032) for {'max_depth': 5, 'max_features': 8, 'n_estimators': 200}
# 0.654 (+/-0.031) for {'max_depth': 5, 'max_features': 8, 'n_estimators': 250}
# 0.670 (+/-0.032) for {'max_depth': 6, 'max_features': 5, 'n_estimators': 150}
# 0.670 (+/-0.032) for {'max_depth': 6, 'max_features': 5, 'n_estimators': 200}
# 0.671 (+/-0.032) for {'max_depth': 6, 'max_features': 5, 'n_estimators': 250}
# 0.677 (+/-0.033) for {'max_depth': 6, 'max_features': 6, 'n_estimators': 150}
# 0.676 (+/-0.033) for {'max_depth': 6, 'max_features': 6, 'n_estimators': 200}
# 0.676 (+/-0.033) for {'max_depth': 6, 'max_features': 6, 'n_estimators': 250}
# 0.677 (+/-0.035) for {'max_depth': 6, 'max_features': 7, 'n_estimators': 150}
# 0.678 (+/-0.035) for {'max_depth': 6, 'max_features': 7, 'n_estimators': 200}
# 0.678 (+/-0.035) for {'max_depth': 6, 'max_features': 7, 'n_estimators': 250}
# 0.683 (+/-0.036) for {'max_depth': 6, 'max_features': 8, 'n_estimators': 150}
# 0.683 (+/-0.036) for {'max_depth': 6, 'max_features': 8, 'n_estimators': 200}
# 0.683 (+/-0.036) for {'max_depth': 6, 'max_features': 8, 'n_estimators': 250}
# 0.694 (+/-0.035) for {'max_depth': 7, 'max_features': 5, 'n_estimators': 150}
# 0.694 (+/-0.036) for {'max_depth': 7, 'max_features': 5, 'n_estimators': 200}
# 0.694 (+/-0.036) for {'max_depth': 7, 'max_features': 5, 'n_estimators': 250}
# 0.696 (+/-0.039) for {'max_depth': 7, 'max_features': 6, 'n_estimators': 150}
# 0.696 (+/-0.038) for {'max_depth': 7, 'max_features': 6, 'n_estimators': 200}
# 0.697 (+/-0.039) for {'max_depth': 7, 'max_features': 6, 'n_estimators': 250}
# 0.697 (+/-0.036) for {'max_depth': 7, 'max_features': 7, 'n_estimators': 150}
# 0.698 (+/-0.037) for {'max_depth': 7, 'max_features': 7, 'n_estimators': 200}
# 0.699 (+/-0.037) for {'max_depth': 7, 'max_features': 7, 'n_estimators': 250}
# 0.703 (+/-0.040) for {'max_depth': 7, 'max_features': 8, 'n_estimators': 150}
# 0.702 (+/-0.040) for {'max_depth': 7, 'max_features': 8, 'n_estimators': 200}
# 0.702 (+/-0.039) for {'max_depth': 7, 'max_features': 8, 'n_estimators': 250}
# 0.709 (+/-0.039) for {'max_depth': 8, 'max_features': 5, 'n_estimators': 150}
# 0.709 (+/-0.039) for {'max_depth': 8, 'max_features': 5, 'n_estimators': 200}
# 0.710 (+/-0.040) for {'max_depth': 8, 'max_features': 5, 'n_estimators': 250}
# 0.711 (+/-0.038) for {'max_depth': 8, 'max_features': 6, 'n_estimators': 150}
# 0.712 (+/-0.038) for {'max_depth': 8, 'max_features': 6, 'n_estimators': 200}
# 0.712 (+/-0.037) for {'max_depth': 8, 'max_features': 6, 'n_estimators': 250}
# 0.712 (+/-0.038) for {'max_depth': 8, 'max_features': 7, 'n_estimators': 150}
# 0.713 (+/-0.040) for {'max_depth': 8, 'max_features': 7, 'n_estimators': 200}
# 0.714 (+/-0.040) for {'max_depth': 8, 'max_features': 7, 'n_estimators': 250}
# 0.715 (+/-0.040) for {'max_depth': 8, 'max_features': 8, 'n_estimators': 150}
# 0.714 (+/-0.040) for {'max_depth': 8, 'max_features': 8, 'n_estimators': 200}
# 0.715 (+/-0.040) for {'max_depth': 8, 'max_features': 8, 'n_estimators': 250}
# 0.720 (+/-0.040) for {'max_depth': 9, 'max_features': 5, 'n_estimators': 150}
# 0.721 (+/-0.040) for {'max_depth': 9, 'max_features': 5, 'n_estimators': 200}
# 0.721 (+/-0.041) for {'max_depth': 9, 'max_features': 5, 'n_estimators': 250}
# 0.722 (+/-0.041) for {'max_depth': 9, 'max_features': 6, 'n_estimators': 150}
# 0.722 (+/-0.041) for {'max_depth': 9, 'max_features': 6, 'n_estimators': 200}
# 0.722 (+/-0.041) for {'max_depth': 9, 'max_features': 6, 'n_estimators': 250}
# 0.723 (+/-0.039) for {'max_depth': 9, 'max_features': 7, 'n_estimators': 150}
# 0.723 (+/-0.039) for {'max_depth': 9, 'max_features': 7, 'n_estimators': 200}
# 0.724 (+/-0.039) for {'max_depth': 9, 'max_features': 7, 'n_estimators': 250}
# 0.724 (+/-0.040) for {'max_depth': 9, 'max_features': 8, 'n_estimators': 150}
# 0.725 (+/-0.039) for {'max_depth': 9, 'max_features': 8, 'n_estimators': 200}
# 0.725 (+/-0.040) for {'max_depth': 9, 'max_features': 8, 'n_estimators': 250}
# 0.727 (+/-0.040) for {'max_depth': 10, 'max_features': 5, 'n_estimators': 150}
# 0.727 (+/-0.040) for {'max_depth': 10, 'max_features': 5, 'n_estimators': 200}
# 0.727 (+/-0.039) for {'max_depth': 10, 'max_features': 5, 'n_estimators': 250}
# 0.729 (+/-0.041) for {'max_depth': 10, 'max_features': 6, 'n_estimators': 150}
# 0.730 (+/-0.040) for {'max_depth': 10, 'max_features': 6, 'n_estimators': 200}
# 0.730 (+/-0.041) for {'max_depth': 10, 'max_features': 6, 'n_estimators': 250}
# 0.730 (+/-0.039) for {'max_depth': 10, 'max_features': 7, 'n_estimators': 150}
# 0.730 (+/-0.038) for {'max_depth': 10, 'max_features': 7, 'n_estimators': 200}
# 0.730 (+/-0.039) for {'max_depth': 10, 'max_features': 7, 'n_estimators': 250}
# 0.731 (+/-0.037) for {'max_depth': 10, 'max_features': 8, 'n_estimators': 150}
# 0.730 (+/-0.038) for {'max_depth': 10, 'max_features': 8, 'n_estimators': 200}
# 0.731 (+/-0.038) for {'max_depth': 10, 'max_features': 8, 'n_estimators': 250}
# 0.732 (+/-0.038) for {'max_depth': 11, 'max_features': 5, 'n_estimators': 150}
# 0.733 (+/-0.039) for {'max_depth': 11, 'max_features': 5, 'n_estimators': 200}
# 0.733 (+/-0.039) for {'max_depth': 11, 'max_features': 5, 'n_estimators': 250}
# 0.734 (+/-0.035) for {'max_depth': 11, 'max_features': 6, 'n_estimators': 150}
# 0.734 (+/-0.035) for {'max_depth': 11, 'max_features': 6, 'n_estimators': 200}
# 0.734 (+/-0.037) for {'max_depth': 11, 'max_features': 6, 'n_estimators': 250}
# 0.734 (+/-0.035) for {'max_depth': 11, 'max_features': 7, 'n_estimators': 150}
# 0.735 (+/-0.037) for {'max_depth': 11, 'max_features': 7, 'n_estimators': 200}
# 0.735 (+/-0.037) for {'max_depth': 11, 'max_features': 7, 'n_estimators': 250}
# 0.736 (+/-0.043) for {'max_depth': 11, 'max_features': 8, 'n_estimators': 150}
# 0.736 (+/-0.043) for {'max_depth': 11, 'max_features': 8, 'n_estimators': 200}
# 0.736 (+/-0.043) for {'max_depth': 11, 'max_features': 8, 'n_estimators': 250}
# 0.737 (+/-0.036) for {'max_depth': 12, 'max_features': 5, 'n_estimators': 150}
# 0.736 (+/-0.036) for {'max_depth': 12, 'max_features': 5, 'n_estimators': 200}
# 0.737 (+/-0.036) for {'max_depth': 12, 'max_features': 5, 'n_estimators': 250}
# 0.736 (+/-0.036) for {'max_depth': 12, 'max_features': 6, 'n_estimators': 150}
# 0.736 (+/-0.036) for {'max_depth': 12, 'max_features': 6, 'n_estimators': 200}
# 0.737 (+/-0.036) for {'max_depth': 12, 'max_features': 6, 'n_estimators': 250}
# 0.738 (+/-0.038) for {'max_depth': 12, 'max_features': 7, 'n_estimators': 150}
# 0.738 (+/-0.037) for {'max_depth': 12, 'max_features': 7, 'n_estimators': 200}
# 0.738 (+/-0.038) for {'max_depth': 12, 'max_features': 7, 'n_estimators': 250}
# 0.738 (+/-0.039) for {'max_depth': 12, 'max_features': 8, 'n_estimators': 150}
# 0.738 (+/-0.038) for {'max_depth': 12, 'max_features': 8, 'n_estimators': 200}
# 0.739 (+/-0.037) for {'max_depth': 12, 'max_features': 8, 'n_estimators': 250}
# 0.736 (+/-0.037) for {'max_depth': 13, 'max_features': 5, 'n_estimators': 150}
# 0.737 (+/-0.038) for {'max_depth': 13, 'max_features': 5, 'n_estimators': 200}
# 0.738 (+/-0.039) for {'max_depth': 13, 'max_features': 5, 'n_estimators': 250}
# 0.739 (+/-0.038) for {'max_depth': 13, 'max_features': 6, 'n_estimators': 150}
# 0.739 (+/-0.038) for {'max_depth': 13, 'max_features': 6, 'n_estimators': 200}
# 0.740 (+/-0.038) for {'max_depth': 13, 'max_features': 6, 'n_estimators': 250}
# 0.737 (+/-0.037) for {'max_depth': 13, 'max_features': 7, 'n_estimators': 150}
# 0.738 (+/-0.039) for {'max_depth': 13, 'max_features': 7, 'n_estimators': 200}
# 0.739 (+/-0.038) for {'max_depth': 13, 'max_features': 7, 'n_estimators': 250}
# 0.738 (+/-0.040) for {'max_depth': 13, 'max_features': 8, 'n_estimators': 150}
# 0.738 (+/-0.040) for {'max_depth': 13, 'max_features': 8, 'n_estimators': 200}
# 0.739 (+/-0.040) for {'max_depth': 13, 'max_features': 8, 'n_estimators': 250}
# 0.738 (+/-0.036) for {'max_depth': 14, 'max_features': 5, 'n_estimators': 150}
# 0.738 (+/-0.036) for {'max_depth': 14, 'max_features': 5, 'n_estimators': 200}
# 0.739 (+/-0.036) for {'max_depth': 14, 'max_features': 5, 'n_estimators': 250}
# 0.740 (+/-0.035) for {'max_depth': 14, 'max_features': 6, 'n_estimators': 150}
# 0.742 (+/-0.036) for {'max_depth': 14, 'max_features': 6, 'n_estimators': 200}
# 0.742 (+/-0.036) for {'max_depth': 14, 'max_features': 6, 'n_estimators': 250}
# 0.737 (+/-0.035) for {'max_depth': 14, 'max_features': 7, 'n_estimators': 150}
# 0.737 (+/-0.035) for {'max_depth': 14, 'max_features': 7, 'n_estimators': 200}
# 0.738 (+/-0.036) for {'max_depth': 14, 'max_features': 7, 'n_estimators': 250}
# 0.741 (+/-0.037) for {'max_depth': 14, 'max_features': 8, 'n_estimators': 150}
# 0.741 (+/-0.037) for {'max_depth': 14, 'max_features': 8, 'n_estimators': 200}
# 0.741 (+/-0.037) for {'max_depth': 14, 'max_features': 8, 'n_estimators': 250}

# %% [markdown]
# ## Подбор max_depth

# %%
parameters_2 = [{'n_estimators': [250, 500, 750, 1000], 
               'max_features': [6],
               'max_depth': np.arange(13, 19)}]

clf_2 = GridSearchCV(estimator=RF(random_state=RANDOM_STATE, n_jobs=-1), 
                   param_grid=parameters_2,
                   scoring='r2',
                   cv=5)

clf_2.fit(train[feats], train[target].values.ravel())

# %%
clf_2.best_params_
# Out:
# {'max_depth': 17, 'max_features': 6, 'n_estimators': 250}

# %%
means = clf_2.cv_results_['mean_test_score']
stds = clf_2.cv_results_['std_test_score']

for mean, std, params in zip(means, stds, clf_2.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# 0.740 (+/-0.038) for {'max_depth': 13, 'max_features': 6, 'n_estimators': 250}
# 0.739 (+/-0.038) for {'max_depth': 13, 'max_features': 6, 'n_estimators': 500}
# 0.739 (+/-0.037) for {'max_depth': 13, 'max_features': 6, 'n_estimators': 750}
# 0.740 (+/-0.037) for {'max_depth': 13, 'max_features': 6, 'n_estimators': 1000}
# 0.742 (+/-0.036) for {'max_depth': 14, 'max_features': 6, 'n_estimators': 250}
# 0.741 (+/-0.036) for {'max_depth': 14, 'max_features': 6, 'n_estimators': 500}
# 0.741 (+/-0.037) for {'max_depth': 14, 'max_features': 6, 'n_estimators': 750}
# 0.741 (+/-0.037) for {'max_depth': 14, 'max_features': 6, 'n_estimators': 1000}
# 0.740 (+/-0.038) for {'max_depth': 15, 'max_features': 6, 'n_estimators': 250}
# 0.740 (+/-0.036) for {'max_depth': 15, 'max_features': 6, 'n_estimators': 500}
# 0.741 (+/-0.036) for {'max_depth': 15, 'max_features': 6, 'n_estimators': 750}
# 0.741 (+/-0.036) for {'max_depth': 15, 'max_features': 6, 'n_estimators': 1000}
# 0.741 (+/-0.036) for {'max_depth': 16, 'max_features': 6, 'n_estimators': 250}
# 0.741 (+/-0.037) for {'max_depth': 16, 'max_features': 6, 'n_estimators': 500}
# 0.742 (+/-0.036) for {'max_depth': 16, 'max_features': 6, 'n_estimators': 750}
# 0.742 (+/-0.036) for {'max_depth': 16, 'max_features': 6, 'n_estimators': 1000}
# 0.743 (+/-0.034) for {'max_depth': 17, 'max_features': 6, 'n_estimators': 250}
# 0.742 (+/-0.036) for {'max_depth': 17, 'max_features': 6, 'n_estimators': 500}
# 0.742 (+/-0.036) for {'max_depth': 17, 'max_features': 6, 'n_estimators': 750}
# 0.742 (+/-0.036) for {'max_depth': 17, 'max_features': 6, 'n_estimators': 1000}
# 0.742 (+/-0.036) for {'max_depth': 18, 'max_features': 6, 'n_estimators': 250}
# 0.742 (+/-0.036) for {'max_depth': 18, 'max_features': 6, 'n_estimators': 500}
# 0.742 (+/-0.036) for {'max_depth': 18, 'max_features': 6, 'n_estimators': 750}
# 0.742 (+/-0.036) for {'max_depth': 18, 'max_features': 6, 'n_estimators': 1000}

# %% [markdown]
# ### Кросс-валидация на всем train

# %%
data_all = data_train.copy()

# %%
data_all = add_square_price(data_all)

# средняя цена за квадратный метр
data_all_stats_square_price_mean = data_all.groupby(['Rooms'], as_index=False)[['square_price']]\
    .mean().rename(columns={'square_price':'mean_square_price'})

data_all = add_stat_distr_1(data_all)
data_all = add_stat_distr_rooms(data_all)
data_all = add_stat_distr_rooms_2(data_all)
data_all = add_stat_square_price(data_all, data_all_stats_square_price_mean)
data_all = fillna_Healthcare_1(data_all)
data_all = fillna_LifeSquare(data_all, data_all)
data_all = prepare_category(data_all)
data_all = prepare_LifeSquare(data_all, data_all)
data_all = prepare_KitchenSquare(data_all, data_all)

# %%
from sklearn.model_selection import cross_val_score

clf_cv = RF(random_state=RANDOM_STATE,
            n_estimators=1000,
            max_depth=17,
            max_features=6,
            n_jobs=-1)

scores = cross_val_score(clf_cv, data_all[feats], data_all[target].values.ravel(), cv=5, scoring='r2')

print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# %% [markdown]
# ### Init data test prepare

# %%
data_test.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0    725          58    2.0  49.882643   33.432782            6.0      6
# 1  15856          74    2.0  69.263183         NaN            1.0      6
# 2   5480         190    1.0  13.597819   15.948246           12.0      2
# 3  15664          47    2.0  73.046609   51.940842            9.0     22
# 4  14275          27    1.0  47.527111   43.387569            1.0     17
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        14.0       1972   0.310199         B         B        11      2748
# 1         1.0       1977   0.075779         B         B         6      1437
# 2         5.0       1909   0.000000         B         B        30      7538
# 3        22.0       2007   0.101872         B         B        23      4583
# 4        17.0       2017   0.072158         B         B         2       629
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 0         1           NaN            0        0       B
# 1         3           NaN            0        2       B
# 2        87        4702.0            5        5       B
# 3         3           NaN            3        3       B
# 4         1           NaN            0        0       A

# %%
# посмотрим на большие значения поля HouseFloor
data_test.loc[data_test['HouseFloor'] > 50]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 651  15864          27    3.0  47.722835   47.098813            9.0     18
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 651        99.0       1977   0.072158         B         B         2       629
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 651         1           NaN            0        0       A

# %%
# заменим 99 на 9
data_test.loc[data_test['HouseFloor'] == 99, 'HouseFloor'] = 9

# %%
# посмотрим на большие значения поля Rooms
data_test.loc[data_test['Rooms'] > 6]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 3398  1435         111   17.0  52.866107   32.528342            8.0     15
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3398        17.0       1987   0.093443         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 3398      4635         5        3300.0            2        4       B

# %%
# заменим на адекватное значение
data_test.loc[data_test['Rooms'] == 17, 'Rooms'] = 2

# %%
# посмотрим на большие значения поля Floor
data_test.loc[data_test['Floor'] > 40]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 3711    414          76    2.0  67.609808   41.175948            5.0     46
# 4698  15759          17    2.0  57.601870   37.744743           10.0     78
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3711        48.0       2002        0.0         B         B         7
# 4698        22.0       1989        0.0         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 3711      1660        39        1786.0            1        5       B
# 4698      5027         4          46.0            1        1       B

# %%
# заменим на адекватное значение
data_test.loc[data_test['Floor'] == 78, 'Floor'] = 22

# %% [markdown]
# ### Data test prepare

# %%
data_test = add_stat_distr_1(data_test)
data_test = add_stat_distr_rooms(data_test)
data_test = add_stat_distr_rooms_2(data_test)
data_test = add_stat_square_price(data_test, data_all_stats_square_price_mean)
data_test = fillna_Healthcare_1(data_test)
data_test = fillna_LifeSquare(data_test, data_all)
data_test = prepare_category(data_test)
data_test = prepare_LifeSquare(data_test, data_all)
data_test = prepare_KitchenSquare(data_test, data_all)

# %% [markdown]
# ### Data test prediction

# %%
clf_cv.fit(data_all[feats], data_all[target].values.ravel())
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=17,
#            max_features=6, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=1000, n_jobs=-1, oob_score=False, random_state=42,
#            verbose=0, warm_start=False)

# %%
data_test['Price'] = clf_cv.predict(data_test[feats])

# %%
data_test.loc[:, ['Id', 'Price']].to_csv('SKabanov_predictions.csv', index=None)
